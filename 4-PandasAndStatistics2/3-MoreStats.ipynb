# %% [markdown]
# # More Stats: The "Titanic Lifeboat" dataset
#
# ## Importing the Lifeboats dataset.
#
#
# There is the file **Lifeboats.csv** has data on Titanic passengers that made it onto a Lifeboat.
#
# Import the file, and have a look at the columns.
#
# Here is the documentation, in case you are interested: http://nicolas.kruchten.com/Rdatasets/doc/vcd/Lifeboats.html
#
# ## Exercise: Cleaning data
#
# First things first. Lets have a look at the dataset. Its got this columns called "Unnamed:0". Thats pretty ugly, so how about we remove it, and save the new dataframe incase we need it laters.
#
# There is a column called **Unnamed: 0** (with a space). This is kind of messy. Lets delete it, and save a new file.
#
# ### Hints
#
# To remove (*drop*) a column from a dataframe **df**, we use:
#
# ```python
# df = df.drop(<column_name>, axis=1)    # drops the column. note: axis = 1 specifies 'column'
# ```
#
# To save a dataframe **df** to a file use:
#
# ```python
# df.to_csv(<new_filename>)
# ```

# %%
### Your code goes here

# %% [markdown]
# # Survivors: Men vs. Women
#
# Load the new cleaned dataset. Now, lets see if there is a differece between the number of men and women that made it to the lifeboats.
#
# We'll plot the data first, then do some stats.
#
# ## Exercise: Histograms
#
# Plot the distribution of the surviving men vs. women as a histogram.
#
# Here is the **matplotlib** documentation of **histogram**: http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.hist
#
# ### hints
#
# ```python
# import maplotlib.pyplot as plt
#
# plt.hist(x)    # plots a histogram of values in 'x'
# plt.hist(x,label='my data')    # plots a histogram of values in 'x', and uses 'label' for legend labels.
# plt.hist(x, y)                 # plots a histogram of 'x' and 'y'
# ```
#
# ### Questions
#
# 1. Make a histogram of the distribution of women on the lifeboats, and men on lifeboats.
#
# 2. Add a title, axis labels and a legend to the histogram.
#
# 3. Customize the way the histogram is displayed (see the documentation for examples). For example, try to make a horizontal histogram instead.

# %%
### Your code goes here...

# %% [markdown]
# # Survivors: Starboard vs. Port
#
# Is there is there a difference between the *total* number of people who made it onto a lifeboat between *starboard* and *port*?
#
# ### hints
#
# Filtering using Boolean selectors:
#
# ```python
# bfilter = df[<column>] == <value>    # returns the boolean vector for all rows where <column> has <value>
# df_filtered = df[bfilter]            # returns a filtered version of the DataFrame
# ```
#
# Using a ttest from stats:
#
# ```python
# result = stats.ttest_ind(a,b)
# print "Result", result.pvalue
# ```
#
# ## Questions
#
# 1. Plot the histogram of survivors from each side (as a histogram).
#
# 2. Is there a statistical difference between the two?

# %%
### Your code goes here...
