# %% [markdown]
# # Part 3: Merging Google n-grams
#
# Lets combine data from two different n-gram queries:
#
# If we have two DataFrames ('df_one' & 'df_two') with a common column (say, 'year'), we can combine the two using **merge**:
# ```python
# df_merged = pd.merge(df_one, df_two, on='year')
# ```
#
# To extract a single column, we can use:
# ```python
# year = df_merged['year']
# bear = df_merged['bear']
# ```
#
# ## questions:
#
# 1. Chose 2 words and plot their occurence frequencies on a timeline (just as before, but now with two lines. **Bonus:** Try adding a legend to the figure, to make clear which is which (google should be able to help)
#
# 2. Is there a correlation between the two? Merge the two datasets (using **pf.merge**, and have a look at the resulting scatterplot between the two. To find out how to make a **scatterplot**, check the **matplotlib gallery**.
#
# 4. Is the difference statistically significant
#
# ## hints
#
# The **stats** pacakge has various functions to measure correlation, including:
#
# ```python
# stats.pearsonr(x,y)    # Pearson correlation
# stats.spearmanr(x,y)   # Spearman correlation
# ```

# %% [markdown]
# ## Solution
#
# none yet!
#
# But, good luck! I'm sure you can do it! :)
